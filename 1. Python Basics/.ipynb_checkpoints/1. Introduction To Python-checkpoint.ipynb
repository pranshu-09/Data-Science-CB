# %% [markdown]
# ## Introduction

# %%
print("Welcome to CB")
# Out:
# Welcome to CB

# %%
a=555
b=666
c=b

# %%
print(a,b,c, sep=" ")
# Out:
# 555 666 666

# %%
c
# Out:
# 666

# %%
# Used to add comments
# I am writing a comment. LOL!!

# %%
a=5

# %%
print(a)
# Out:
# 5

# %%
# Press M to change the cell to Markdown
# Press Y to change the cell to Code

# %% [markdown]
# I am Groot

# %% [markdown]
# print("HI")

# %%
print("Hi")
# Out:
# Hi

# %% [markdown]
# Here, I'm learning python

# %% [markdown]
# Markdown is used to add line just like commmands used in HTML

# %% [markdown]
# <b> Bold</b>

# %% [markdown]
# <ol>
# <li>Apple</li>
# <li>Mango</li>
# </ol>

# %% [markdown]
# <h1> Heading </h1>

# %% [markdown]
# Start the line with a '#' to convert the line in the largest heading

# %%
# Press 'DD' to delete a cell
# Press Z to bring back the cell

# %%
c
# Out:
# 666

# %%
a == 555
# Out:
# True

# %%
b == c
# Out:
# True

# %%
b is c
# Out:
# True

# %%
id(b)
# Out:
# 2149114297680

# %%
id(c)
# Out:
# 2149114297680

# %%
id(a)
# Out:
# 2149114297552

# %%
c = 777

# %%
id(c)
# Out:
# 2149124387696

# %%
b==c
# Out:
# False

# %%
b is c
# Out:
# False

# %%
c=666

# %%
d=666

# %%
c==d
# Out:
# True

# %%
c is d
# Out:
# False

# %%
c=661

# %%
c=66

# %%
d=66

# %%
c is d
# Out:
# True

# %%
c=-5

# %%
d=-5

# %%
c is d
# Out:
# True

# %%
c=-4

# %%
d=-4

# %%
c is d
# Out:
# True

# %%
id(c)
# Out:
# 140723900424432

# %%
id(d)
# Out:
# 140723900424432

# %% [markdown]
# ## Datatypes

# %% [markdown]
# ### Int and float

# %%
2**1000
# Out:
# 

# %%
2**10
# Out:
# 1024

# %%
f=655418791535241528744148794165018741562150541520456510689541052315341899868534154

# %%
type(f)
# Out:
# int

# %%
g=f*f

# %%
g
# Out:
# 429573792297516392611446996083862336024253977188642372696283505889359958509439815568019944398827783816217558094296227248997192062780998306876636691788468664495716

# %%
type(g)
# Out:
# int

# %%
float(g)
# Out:
# 4.2957379229751637e+161

# %% [markdown]
# <b>
# Range of int is practically infinite <br>
# Float has a particular range
# </b>

# %%
item = 55.77

# %%
h = int(item)

# %%
h
# Out:
# 55

# %%
l=0

# %% [markdown]
# ### Strings

# %% [markdown]
# Strings are iterable

# %%
d="hi"

# %%
d
# Out:
# 'hi'

# %%
line = "Hello World"

# %%
line[2]
# Out:
# 'l'

# %%
# line[3] = 'p'
# We cannot change the value of the object, i.e. string object does not support item assignment

# %% [markdown]
# ### Slicing

# %%
line[0:3]
# Out:
# 'Hel'

# %%
line[1:8]
# Out:
# 'ello Wo'

# %%
line[9:8]
# Out:
# ''

# %%
line[9:20]
# Out:
# 'ld'

# %%
line[15:20]
# Out:
# ''

# %%
line[3:3]
# Out:
# ''

# %%
line[4:0]
# Out:
# ''

# %% [markdown]
# ### Different Functions of Strings

# %%
first = "hello"

# %%
second = " world"

# %%
first+second
# Out:
# 'hello world'

# %%
first == second
# Out:
# False

# %%
first.capitalize()
# Out:
# 'Hello'

# %%
first = "hello, my name is Pranshu"

# %%
first.capitalize()
# Out:
# 'Hello, my name is pranshu'

# %%
first.count("l")
# Out:
# 2

# %%
first.count("llo")
# Out:
# 1

# %% [markdown]
# Format

# %%
line = "Hello my name is {} and i am {} years old"   # {} -> Place Holder

# %%
line.format("Pranshu",18)
# Out:
# 'Hello my name is Pranshu and i am 18 years old'

# %%
name = input("Enter your name : ")
age = input("Enter your age")
# Out:
# Enter your name :  Pranshu Bansal
# Enter your age 18

# %%
line.format(name,age)
# Out:
# 'Hello my name is Pranshu Bansal and i am 18 years old'

# %%
a=input()
b=input()
# Out:
#  15
#  12

# %%
print(a+b)  # input takes values in form of string by default
# Out:
# 1512

# %%
a=int(input())  # We can change it explicitly to input int value
b=int(input())
# Out:
#  15
#  12

# %%
print(a+b)
# Out:
# 27

# %%
from PIL import Image

# %%
img = Image.open("Desktop/DS Live/ 1. Python Basics/panda.jpg")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-116-824b183338f4> in <module>
# ----> 1 img = Image.open("Desktop/DS Live/ 1. Python Basics/panda.jpg")
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2807
#    2808     if filename:
# -> 2809         fp = builtins.open(filename, "rb")
#    2810         exclusive_fp = True
#    2811
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Desktop/DS Live/ 1. Python Basics/panda.jpg'

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1152x648 at 0x254A042EAC8>

# %%
second = img.resize(size=(80,40))

# %%
second
# Out:
# <PIL.Image.Image image mode=RGB size=80x40 at 0x2549EB3E488>
