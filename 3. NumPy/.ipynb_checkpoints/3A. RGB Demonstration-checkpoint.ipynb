# %%
import numpy as np
from PIL import Image

# %%
img = Image.open("panda.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=360x240 at 0x184A4A29F48>

# %%
small = img.resize((400, 300))

# %%
small
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x184A4A29EC8>

# %%
type(small)
# Out:
# PIL.Image.Image

# %%
# We need to convert this PIL.Image.Image into a numpy array

# %%
panda = np.array(small)

# %%
type(panda)
# Out:
# numpy.ndarray

# %%
panda.shape
# Out:
# (300, 400, 3)
